# %% [markdown]
# # Contrôle de la source de courant (HMP Rohde&Schwarz)

# %%
import pyvisa
rm = pyvisa.ResourceManager()
mxg=rm.open_resource('mxg')

# %%
# Check connection
mxg.query('*IDN?')
# Out:
# 'Agilent Technologies, N5183B, MY53271214, B.01.65\n'

# %% [markdown]
# ## Modifie la fréquence

# %%
freq = 7.55e9
mxg.write(f'SOUR:FREQ {freq}')
# Out:
# 24
