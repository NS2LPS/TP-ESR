# %% [markdown]
# # TP Résonance Paramagnétique Electronique
#
# Vos Notebooks et fichiers de mesure doivent être sauvés dans le répertoire correspondant à votre groupe. Vous trouverez dans le répertoire racine quelques fichiers d'example pour communiquer avec les appareils et suaver les donner.
#
# - [Contrôle du vna (ZND Rohde&Schwarz)](znd.ipynb)
# - [Contrôle de l'oscillo (DSO-X Keysight)](dsox.ipynb)
# - [Contrôle du lockin (HF2LI Zürich Instruments)](hf2li.ipynb)
# - [Contrôle de la source de courant (HMP Rohde&Schwarz)](hmp.ipynb)
# - [Contrôle de la source micro-onde (MXG Agilent)](mxg.ipynb)
# - [Sauver des données au format HDF5](hdf5.ipynb)
